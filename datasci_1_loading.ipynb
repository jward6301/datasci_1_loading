# %% [markdown]
# <a href="https://colab.research.google.com/github/jward6301/datasci_1_loading/blob/main/datasci_1_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# CSV Files

# %%
df = pd.DataFrame
df1 = pd.read_csv('drivers.csv')
df1.head (10)
# Out:
#    driverId   driverRef number code   forename     surname         dob  \
# 0         1    hamilton     44  HAM      Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI       Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS       Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO   Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV     Heikki  Kovalainen  1981-10-19
# 5         6    nakajima     \N  NAK     Kazuki    Nakajima  1985-01-11
# 6         7    bourdais     \N  BOU  Sébastien    Bourdais  1979-02-28
# 7         8   raikkonen      7  RAI       Kimi   Räikkönen  1979-10-17
# 8         9      kubica     88  KUB     Robert      Kubica  1984-12-07
# 9        10       glock     \N  GLO       Timo       Glock  1982-03-18
#
#   nationality                                                url
# 0     British        http://en.wikipedia.org/wiki/Lewis_Hamilton
# ...

# %%
df1.columns
# Out:
# Index(['driverId', 'driverRef', 'number', 'code', 'forename', 'surname', 'dob',
#        'nationality', 'url'],
#       dtype='object')

# %% [markdown]
# The different columns meanings are to organzie each person on the list and provide the information in the column, such as URL is where you can find their information and driverref is their last name.

# %%
df = pd.DataFrame
df2 = pd.read_csv('netflix_titles.csv')
df2.head (10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df2.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# For this dataset as well the information provided in the colums relate to its name and provides overall informaiton on each movie or TV show on Netflix.

# %%
df = pd.DataFrame
df3 = pd.read_csv('sets.csv')
df3.head (10)
# Out:
#   set_num                          name  year  theme_id  num_parts
# 0    00-1               Weetabix Castle  1970       414        471
# 1  0011-2             Town Mini-Figures  1978        84         12
# 2  0011-3    Castle 2 for 1 Bonus Offer  1987       199          2
# 3  0012-1            Space Mini-Figures  1979       143         12
# 4  0013-1            Space Mini-Figures  1979       143         12
# 5  0014-1            Space Mini-Figures  1979       143         12
# 6  0015-1            Space Mini-Figures  1979       143         18
# 7  0016-1           Castle Mini Figures  1978       186         15
# 8    00-2  Weetabix Promotional House 1  1976       413        147
# 9    00-3  Weetabix Promotional House 2  1976       413        149

# %%
df3.columns
# Out:
# Index(['set_num', 'name', 'year', 'theme_id', 'num_parts'], dtype='object')

# %% [markdown]
# This data sets relates to Lego Sets released. It lists their internal set number, name, year released, number of pieces in the set and their theme/topic number.

# %% [markdown]
# XLSX/Excel Files

# %%
df = pd.DataFrame
df4 = pd.read_excel('sampledatafootballplayers.xlsx')
df4.head (10)
# Out:
#    Year         Team              NAME    No.  Pos    Ht   Wt   Age Exp  \
# 0  2022  New Orleans      Paulson Adebo  29.0   CB   6-1  192  23.0   2
# 1  2022      Arizona         Zach Allen  94.0   DE   6-4  281  24.0   4
# 2  2022  New Orleans        Kiko Alonso  47.0  OLB   6-3  239   NaN   R
# 3  2022      Arizona   Stephen Anderson  89.0   TE   6-2  230  29.0   5
# 4  2022  New Orleans       Josh Andrews  68.0    G   6-2  298  31.0   7
# 5  2022      Arizona     Marcell Ateman  84.0   WR   6-4  215   NaN   R
# 6  2022      Arizona    Andre Baccellia  82.0   WR  5-10  175  25.0   1
# 7  2022      Arizona        Budda Baker   3.0    S  5-10  195  26.0   6
# 8  2022  New Orleans       Kawaan Baker  87.0   WR   6-1  215  23.0   1
# 9  2022      Arizona  Darrell Baker Jr.  31.0   CB   6-1  190  24.0   R
#
#             College  ...   LastName Ft  In  Inches  NumGrp Unnamed: 16  \
# 0          Stanford  ...      Adebo  6   1      73   20-29         NaN
# ...

# %%
df4.columns
# Out:
# Index(['Year', 'Team', 'NAME ', 'No.', 'Pos', 'Ht', 'Wt', 'Age', 'Exp',
#        'College', 'FirstName', 'LastName', 'Ft', 'In', 'Inches', 'NumGrp',
#        'Unnamed: 16', 'Unnamed: 17', 'Num', 'NumGrp.1', 'Players'],
#       dtype='object')

# %% [markdown]
# This database relates to football players in the US and each column related to different information about each player.

# %%
df = pd.DataFrame
df5 = pd.read_excel('sampledatahockey.xlsx')
df5.head (10)
# Out:
#    ID   Team Country     NameF      NameL  Weight Height        DOB  \
# 0   1  Women  Canada    Meghan     Agosta     148    5'7 1987-02-12
# 1   2  Women  Canada   Rebecca   Johnston     148    5'9 1989-09-24
# 2   3  Women  Canada     Laura     Stacey     156   5'10 1994-05-05
# 3   4  Women  Canada  Jennifer  Wakefield     172   5'10 1989-06-15
# 4   5  Women  Canada   Jillian   Saulnier     144    5'5 1992-03-07
# 5   6  Women  Canada   Mélodie     Daoust     159    5'6 1992-01-07
# 6   7  Women  Canada    Bailey       Bram     150    5'8 1990-09-05
# 7   8  Women  Canada   Brianne     Jenner     156    5'9 1991-05-04
# 8   9  Women  Canada     Sarah      Nurse     140    5'8 1995-01-04
# 9  10  Women  Canada     Haley      Irwin     170    5'7 1988-06-06
#
#       Hometown  Prov      Pos  Age  HeightFt  HtIn  BMI
# 0      Ruthven  Ont.  Forward   36  5.583333    67   23
# 1      Sudbury  Ont.  Forward   33  5.750000    69   22
# ...

# %%
df5.columns
# Out:
# Index(['ID', 'Team', 'Country', 'NameF', 'NameL', 'Weight', 'Height', 'DOB',
#        'Hometown', 'Prov', 'Pos', 'Age', 'HeightFt', 'HtIn', 'BMI'],
#       dtype='object')

# %% [markdown]
# This database relates to hockey players in the US and Canada and each column related to different information about each player.

# %%
df = pd.DataFrame
df6 = pd.read_excel('sampledatasafety.xlsx')
df6.head (10)
# Out:
#         Date Injury Location  Gender Age Group   Incident Type  Days Lost  \
# 0 2020-01-01        Multiple    Male     25-34            Burn        0.0
# 1 2020-01-03             NaN    Male     35-49         Vehicle        0.5
# 2 2020-01-03             Eye    Male     18-24             Cut        0.0
# 3 2020-01-04            Legs  Female       50+  Falling object        0.0
# 4 2020-01-07            Legs    Male     25-34         Lifting        0.0
# 5 2020-01-11             NaN  Female       50+   Crush & Pinch        0.0
# 6 2020-01-11            Neck    Male     25-34   Crush & Pinch        3.5
# 7 2020-01-12            Feet    Male     35-49            Burn        1.5
# 8 2020-01-15             NaN    Male     18-24            Fall        0.0
# 9 2020-01-16            Arms    Male       50+   Crush & Pinch        4.5
#
#         Plant Report Type      Shift      Department  Incident Cost WkDay  \
# 0        Iowa   Near Miss  Afternoon        Painting              0   Wed
# ...

# %%
df6.columns
# Out:
# Index(['data', 'version'], dtype='object')

# %% [markdown]
# This database comploied informaiton regarding different accidents throughout the US for a safety analysis. Each column related to different information about the accident.

# %% [markdown]
# JSON Files

# %%
df = pd.DataFrame
df7 = pd.read_json('dev-v1.1.json')
df7.head (10)
# Out:
#                                                 data  version
# 0  {'title': 'Super_Bowl_50', 'paragraphs': [{'co...      1.1
# 1  {'title': 'Warsaw', 'paragraphs': [{'context':...      1.1
# 2  {'title': 'Normans', 'paragraphs': [{'context'...      1.1
# 3  {'title': 'Nikola_Tesla', 'paragraphs': [{'con...      1.1
# 4  {'title': 'Computational_complexity_theory', '...      1.1
# 5  {'title': 'Teacher', 'paragraphs': [{'context'...      1.1
# 6  {'title': 'Martin_Luther', 'paragraphs': [{'co...      1.1
# 7  {'title': 'Southern_California', 'paragraphs':...      1.1
# 8  {'title': 'Sky_(United_Kingdom)', 'paragraphs'...      1.1
# 9  {'title': 'Victoria_(Australia)', 'paragraphs'...      1.1

# %%
df7.columns
# Out:
# Index(['data', 'version'], dtype='object')

# %% [markdown]
# This database related to different comments gathered about different events. The data column states what was said, who said it, the country, and what event or object it relates to. The version is the version of information gathered.

# %%
df = pd.DataFrame
df8 = pd.read_json('GCB2022v27_MtCO2_flat_metadata.json')
df8.head (10)
# Out:
#                                               fields
# 0  {'name': 'Country', 'title': 'Country name', '...
# 1  {'name': 'ISO 3166-1 alpha-3', 'title': 'ISO c...
# 2  {'name': 'Year', 'title': 'Year', 'note': 'In ...
# 3  {'name': 'Total', 'title': 'Total fossil CO2 e...
# 4  {'name': 'Coal', 'title': 'Fossil CO2 emission...
# 5  {'name': 'Oil', 'title': 'Fossil CO2 emissions...
# 6  {'name': 'Gas', 'title': 'Fossil CO2 emissions...
# 7  {'name': 'Cement', 'title': 'Fossil CO2 emissi...
# 8  {'name': 'Flaring', 'title': 'Fossil CO2 emiss...
# 9  {'name': 'Other', 'title': 'Fossil CO2 emissio...

# %%
df8.columns
# Out:
# Index(['fields'], dtype='object')

# %% [markdown]
# This data set is a dictionary of different words. The fields column states what it is, what data type it is, its title or what category it belongs under, and more depending on what the word is.

# %%
df = pd.DataFrame
df9 = pd.read_json('file1995-04-08.json')
df9.head (10)
# Out:
#                                                         links  element_count  \
# next        https://api.nasa.gov/neo/rest/v1/feed?start_da...              4
# prev        https://api.nasa.gov/neo/rest/v1/feed?start_da...              4
# self        https://api.nasa.gov/neo/rest/v1/feed?start_da...              4
# 1995-04-08                                                NaN              4
#
#                                            near_earth_objects
# next                                                      NaN
# prev                                                      NaN
# self                                                      NaN
# 1995-04-08  [{'links': {'self': 'https://api.nasa.gov/neo/...

# %%
df9.columns
# Out:
# Index(['links', 'element_count', 'near_earth_objects'], dtype='object')

# %% [markdown]
# This dataset is provided by NASA. It provied informaiton regarding different asteriods based on the month and year. THe link cplumn provides the link wehre you can find out mroe information. Element count is the element count.
